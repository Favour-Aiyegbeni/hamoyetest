# %%
import numpy as np
import pandas as pd

# %%
energy_data = pd.read_csv("quiz.csv")

# %%
A = [1,2,3,4,5,6]
B = [13, 21, 34]

# %%
A.append(B)

# %%
print(A.append(B))
# Out:
# None

# %%
print(A.extend(B))
# Out:
# None

# %%
import numpy as np

# %%
hexagon = np.array([[1,0,0],[0,1,0],[0,0,1]])

# %%
print(hexagon)
# Out:
# [[1 0 0]
#  [0 1 0]
#  [0 0 1]]

# %%
energy_data.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
there = energy_data.groupby("fuel_type_code_pudl")
there["fuel_cost_per_unit_burned"].describe()
# Out:
#                        count         mean           std     min      25%  \
# fuel_type_code_pudl
# coal                  8547.0    67.421830    943.771433    0.00  23.9585
# gas                  11486.0    13.659397    163.286631    0.00   3.2300
# nuclear                818.0  4955.157002  14291.929749    0.00   1.6015
# oil                   8064.0   168.877086   2406.101479    0.00  37.6100
# other                  167.0    18.253856     29.016882 -119.04   2.6325
# waste                  441.0    19.518122     29.988017 -276.08  10.3350
#
#                          50%       75%         max
# fuel_type_code_pudl
# coal                 33.3180  44.66800   44033.320
# gas                   4.6500   6.96000   10490.000
# nuclear              32.5200  50.85525   69785.215
# oil                  68.9455  98.68925  139358.000
# other                 9.0640  20.05500     134.547
# waste                21.9330  32.65000     132.291

# %%
energy_data.describe()
# Out:
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      29523.000000  29523.000000     2.952300e+04         29523.000000
# mean         118.601836   2005.806050     2.622119e+06             8.492111
# std           74.178353      7.025483     9.118004e+06            10.600220
# min            1.000000   1994.000000     1.000000e+00             0.000001
# 25%           55.000000   2000.000000     1.381700e+04             1.024000
# 50%          122.000000   2006.000000     2.533220e+05             5.762694
# 75%          176.000000   2012.000000     1.424034e+06            17.006000
# max          514.000000   2018.000000     5.558942e+08           341.260000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count               29523.000000                  2.952300e+04
# mean                  208.649031                  9.175704e+02
# std                  2854.490090                  6.877593e+04
# ...

# %%
energy_data.skew()
# Out:
# utility_id_ferc1                  0.605070
# report_year                       0.006953
# fuel_qty_burned                  15.851495
# fuel_mmbtu_per_unit               4.135217
# fuel_cost_per_unit_burned        19.787440
# fuel_cost_per_unit_delivered    105.014227
# fuel_cost_per_mmbtu             171.675535
# dtype: float64

# %%
energy_data.kurtosis()
# Out:
# utility_id_ferc1                    1.088432
# report_year                        -1.145656
# fuel_qty_burned                   651.369450
# fuel_mmbtu_per_unit                55.595695
# fuel_cost_per_unit_burned         485.255851
# fuel_cost_per_unit_delivered    11765.054226
# fuel_cost_per_mmbtu             29489.132594
# dtype: float64

# %%
energy_data.isna().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
totalrows = np.product(energy_data.shape[0])

# %%
percentage = ((180/ (totalrows)) *100).round(3)

# %%
print(percentage)
# Out:
# 0.61

# %%
energy_data.isna()
# Out:
#        record_id  utility_id_ferc1  report_year  plant_name_ferc1  \
# 0          False             False        False             False
# 1          False             False        False             False
# 2          False             False        False             False
# 3          False             False        False             False
# 4          False             False        False             False
# ...          ...               ...          ...               ...
# 29518      False             False        False             False
# 29519      False             False        False             False
# 29520      False             False        False             False
# 29521      False             False        False             False
# 29522      False             False        False             False
#
#        fuel_type_code_pudl  fuel_unit  fuel_qty_burned  fuel_mmbtu_per_unit  \
# 0                    False      False            False                False
# ...

# %%
energy_data.isna().mean()
# Out:
# record_id                       0.000000
# utility_id_ferc1                0.000000
# report_year                     0.000000
# plant_name_ferc1                0.000000
# fuel_type_code_pudl             0.000000
# fuel_unit                       0.006097
# fuel_qty_burned                 0.000000
# fuel_mmbtu_per_unit             0.000000
# fuel_cost_per_unit_burned       0.000000
# fuel_cost_per_unit_delivered    0.000000
# fuel_cost_per_mmbtu             0.000000
# dtype: float64

# %%
energy_data.isna().mode()
# Out:
#    record_id  utility_id_ferc1  report_year  plant_name_ferc1  \
# 0      False             False        False             False
#
#    fuel_type_code_pudl  fuel_unit  fuel_qty_burned  fuel_mmbtu_per_unit  \
# 0                False      False            False                False
#
#    fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# 0                      False                         False
#
#    fuel_cost_per_mmbtu
# 0                False

# %%
correlation = energy_data.corr()
correlation
# Out:
#                               utility_id_ferc1  report_year  fuel_qty_burned  \
# utility_id_ferc1                      1.000000     0.093323        -0.057447
# report_year                           0.093323     1.000000         0.012952
# fuel_qty_burned                      -0.057447     0.012952         1.000000
# fuel_mmbtu_per_unit                  -0.066946    -0.110853        -0.080946
# fuel_cost_per_unit_burned            -0.037863     0.013599        -0.018535
# fuel_cost_per_unit_delivered         -0.016414    -0.014043        -0.003551
# fuel_cost_per_mmbtu                   0.006122     0.010261        -0.001896
#
#                               fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# utility_id_ferc1                        -0.066946                  -0.037863
# report_year                             -0.110853                   0.013599
# fuel_qty_burned                         -0.080946                  -0.018535
# ...

# %%
correlation["fuel_cost_per_unit_burned"].sort_values(ascending=True)
# Out:
# utility_id_ferc1               -0.037863
# fuel_qty_burned                -0.018535
# fuel_mmbtu_per_unit            -0.010034
# fuel_cost_per_mmbtu            -0.000437
# fuel_cost_per_unit_delivered    0.011007
# report_year                     0.013599
# fuel_cost_per_unit_burned       1.000000
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
energy_data.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
fuel_types = energy_data.groupby([ "report_year", "fuel_type_code_pudl"])
grouped_data = fuel_types["fuel_cost_per_unit_burned"].sum()
grouped_data.head(30)
# Out:
# report_year  fuel_type_code_pudl
# 1994         coal                    14984.572
#              gas                     10792.496
#              nuclear                227983.354
#              oil                      9362.194
#              other                     116.737
#              waste                      52.762
# 1995         coal                    14571.785
#              gas                      9087.905
#              nuclear                384152.639
#              oil                     17858.281
#              other                     183.577
#              waste                    -192.699
# 1996         coal                    12694.803
#              gas                      1467.390
#              nuclear                 66657.887
#              oil                      5357.028
#              other                     160.075
#              waste                      88.092
# 1997         coal                    43742.178
# ...

# %%
((11902.597-14984.572)/14984.572)*100
# Out:
# -20.567654518260518

# %%
answer= energy_data.groupby("report_year")
theanswer= answer["fuel_cost_per_unit_delivered"].describe()
theanswer
# Out:
#               count          mean            std      min      25%      50%  \
# report_year
# 1994         1235.0     63.636060    1288.748659  -58.800  2.32600  13.1560
# 1995         1201.0     32.735269     173.849821  -85.640  1.80600   5.1140
# 1996         1088.0   9196.705948  244767.437600  -44.050  2.93500  16.2700
# 1997         1094.0  11140.197239  256945.853368  -38.972  2.94650  14.4515
# 1998         1107.0    287.154420    8172.214382  -43.747  2.40000   3.4750
# 1999         1050.0     25.551627     137.826776  -32.970  2.52700   3.5750
# 2000         1373.0    985.362877   31576.526616 -174.670  4.37000  19.4700
# 2001         1356.0     60.050396     947.767770  -37.790  4.35950  21.2150
# 2002         1205.0     47.594361     906.266622  -60.290  3.72400  17.8940
# 2003         1211.0     55.663493     996.166868 -118.340  5.93000  21.9670
# 2004         1192.0    139.524275    3848.790040 -313.410  6.51500  20.9000
# ...
